# %% [markdown]
# <a href="https://colab.research.google.com/github/Vishal-3600/Leader/blob/main/featureEngineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('employee_promotion_data.csv')

# %%
df.head()
# Out:
#    Age  Salary  YearsExperience  NumCertifications  JobSatisfaction  \
# 0   50   32717               20                  8                3
# 1   36   89676               14                  9                4
# 2   29   57952                2                  1                3
# 3   42  116444                9                  2                5
# 4   40   72460               20                  9                3
#
#           JobTitle    Education       City  Promotion
# 0       HR Manager     Bachelor  Hyderabad          0
# 1     Data Analyst          PhD    Chennai          0
# 2     Data Analyst  High School  Hyderabad          0
# 3  Project Manager     Bachelor  Bangalore          1
# 4  Project Manager  High School      Delhi          1

# %%
df.shape
# Out:
# (1000, 9)

# %% [markdown]
# # **Feature Encoding**

# %%
from sklearn.preprocessing import LabelEncoder

#Copying the original dataset
df_encoded=df.copy()

#Label Encoding for promotion (mostly for target variable)
label_encoded=LabelEncoder()
df_encoded["Promotion_Enc"]=label_encoded.fit_transform(df_encoded["Promotion"])
df_encoded.head()
# Out:
#    Age  Salary  YearsExperience  NumCertifications  JobSatisfaction  \
# 0   50   32717               20                  8                3
# 1   36   89676               14                  9                4
# 2   29   57952                2                  1                3
# 3   42  116444                9                  2                5
# 4   40   72460               20                  9                3
#
#           JobTitle    Education       City  Promotion  Promotion_Enc
# 0       HR Manager     Bachelor  Hyderabad          0              0
# 1     Data Analyst          PhD    Chennai          0              0
# 2     Data Analyst  High School  Hyderabad          0              0
# 3  Project Manager     Bachelor  Bangalore          1              1
# 4  Project Manager  High School      Delhi          1              1

# %%
#label encoding with order for education (for feature having ordinal categories)
education_encoded={"High School":0,"Bachelor":1,"Master":2,"PhD":3}
df_encoded["Education_Enc"]=df_encoded["Education"].map(education_encoded)
df_encoded.head()
# Out:
#    Age  Salary  YearsExperience  NumCertifications  JobSatisfaction  \
# 0   50   32717               20                  8                3
# 1   36   89676               14                  9                4
# 2   29   57952                2                  1                3
# 3   42  116444                9                  2                5
# 4   40   72460               20                  9                3
#
#           JobTitle    Education       City  Promotion  Promotion_Enc  \
# 0       HR Manager     Bachelor  Hyderabad          0              0
# 1     Data Analyst          PhD    Chennai          0              0
# 2     Data Analyst  High School  Hyderabad          0              0
# 3  Project Manager     Bachelor  Bangalore          1              1
# 4  Project Manager  High School      Delhi          1              1
#
#    Education_Enc
# 0              1
# 1              3
# 2              0
# 3              1
# 4              0

# %%
# One-hot Encoding for City
df_encoded=pd.get_dummies(df_encoded,columns=["City"],prefix="City")
df_encoded.head()
# Out:
#    Age  Salary  YearsExperience  NumCertifications  JobSatisfaction  \
# 0   50   32717               20                  8                3
# 1   36   89676               14                  9                4
# 2   29   57952                2                  1                3
# 3   42  116444                9                  2                5
# 4   40   72460               20                  9                3
#
#           JobTitle    Education  Promotion  Promotion_Enc  Education_Enc  \
# 0       HR Manager     Bachelor          0              0              1
# 1     Data Analyst          PhD          0              0              3
# 2     Data Analyst  High School          0              0              0
# 3  Project Manager     Bachelor          1              1              1
# 4  Project Manager  High School          1              1              0
#
#    City_Bangalore  City_Chennai  City_Delhi  City_Hyderabad  City_Mumbai  \
# 0           False         False       False            True        False
# 1           False          True       False           False        False
# 2           False         False       False            True        False
# 3            True         False       False           False        False
# 4           False         False        True           False        False
#
#    City_Pune
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False

# %%
#Frequency Encoding for JobTitle
job_title_freq=df_encoded["JobTitle"].value_counts(normalize=True)*1000
df_encoded["JobTitle_Enc"]=df_encoded["JobTitle"].map(job_title_freq)
df_encoded.head()
# Out:
#    Age  Salary  YearsExperience  NumCertifications  JobSatisfaction  \
# 0   50   32717               20                  8                3
# 1   36   89676               14                  9                4
# 2   29   57952                2                  1                3
# 3   42  116444                9                  2                5
# 4   40   72460               20                  9                3
#
#           JobTitle    Education  Promotion  Promotion_Enc  Education_Enc  \
# 0       HR Manager     Bachelor          0              0              1
# 1     Data Analyst          PhD          0              0              3
# 2     Data Analyst  High School          0              0              0
# 3  Project Manager     Bachelor          1              1              1
# 4  Project Manager  High School          1              1              0
#
#    City_Bangalore  City_Chennai  City_Delhi  City_Hyderabad  City_Mumbai  \
# 0           False         False       False            True        False
# 1           False          True       False           False        False
# 2           False         False       False            True        False
# 3            True         False       False           False        False
# 4           False         False        True           False        False
#
#    City_Pune  JobTitle_Enc
# 0      False         208.0
# 1      False         199.0
# 2      False         199.0
# 3      False         206.0
# 4      False         206.0

# %%
#Target Encoding for Education (Encoding it based on the average promotion rate)
education_target_mean=df_encoded.groupby("Education")["Promotion_Enc"].mean().to_dict()
df_encoded["Education_Target_Enc"]=df_encoded["Education"].map(education_target_mean)
df_encoded.head()
# Out:
#    Age  Salary  YearsExperience  NumCertifications  JobSatisfaction  \
# 0   50   32717               20                  8                3
# 1   36   89676               14                  9                4
# 2   29   57952                2                  1                3
# 3   42  116444                9                  2                5
# 4   40   72460               20                  9                3
#
#           JobTitle    Education  Promotion  Promotion_Enc  Education_Enc  \
# 0       HR Manager     Bachelor          0              0              1
# 1     Data Analyst          PhD          0              0              3
# 2     Data Analyst  High School          0              0              0
# 3  Project Manager     Bachelor          1              1              1
# 4  Project Manager  High School          1              1              0
#
#    City_Bangalore  City_Chennai  City_Delhi  City_Hyderabad  City_Mumbai  \
# 0           False         False       False            True        False
# 1           False          True       False           False        False
# 2           False         False       False            True        False
# 3            True         False       False           False        False
# 4           False         False        True           False        False
#
#    City_Pune  JobTitle_Enc  Education_Target_Enc
# 0      False         208.0              0.509158
# 1      False         199.0              0.549407
# 2      False         199.0              0.522267
# 3      False         206.0              0.509158
# 4      False         206.0              0.522267

# %%
#scaling the salary
from sklearn.preprocessing import StandardScaler, MinMaxScaler

#copying the dataset
df_scaled =df_encoded.copy()

#Standard Scaler
standard_scaler=StandardScaler()
df_scaled["Salary_StandardScaled"]=standard_scaler.fit_transform(df_scaled[["Salary"]])

#Min-max Scaler
minmax_scaler=MinMaxScaler()
df_scaled["Salary_MinMaxScaled"]=minmax_scaler.fit_transform(df_scaled[["Salary"]])

#Displaying the first few rows
df_scaled[["Salary","Salary_StandardScaled","Salary_MinMaxScaled"]].head()
# Out:
#    Salary  Salary_StandardScaled  Salary_MinMaxScaled
# 0   32717              -1.680658             0.022195
# 1   89676               0.001623             0.497999
# 2   57952              -0.935344             0.232994
# 3  116444               0.792215             0.721605
# 4   72460              -0.506851             0.354186

# %%
df_scaled[["Salary","Salary_StandardScaled","Salary_MinMaxScaled"]].describe()
# Out:
#               Salary  Salary_StandardScaled  Salary_MinMaxScaled
# count    1000.000000           1.000000e+03          1000.000000
# mean    89621.044000           1.545430e-16             0.497540
# std     33875.131043           1.000500e+00             0.282974
# min     30060.000000          -1.759133e+00             0.000000
# 25%     59758.500000          -8.819888e-01             0.248085
# 50%     88329.500000          -3.814569e-02             0.486751
# 75%    117161.000000           8.133913e-01             0.727594
# max    149771.000000           1.776526e+00             1.000000

# %%
import pandas as pd
df=pd.read_csv('/retail_customers_10000.csv')

# %%
display(df.head())
# Out:
#    Customer ID                 Name  Age  Gender Signup Date Last Purchase  \
# 0            1         Allison Hill   58    Male  2021-07-12    2022-02-13
# 1            2      Cristian Santos   65    Male  2022-11-24    2024-09-05
# 2            3  Christopher Bernard   20    Male  2022-01-04    2022-06-11
# 3            4         Jamie Arnold   53    Male  2024-02-09    2025-06-11
# 4            5       Victoria Wyatt   46  Female  2024-04-07    2024-06-24
#
#    Total Purchases  Total Spent ($)  Country                      Email  \
# 0                2          3720.67  Germany  garzaanthony@robinson.org
# 1               44          3716.31    China        zlawrence@blake.biz
# 2                6          1132.26    China           wdavis@baker.com
# 3               46          3266.93    China    janetwilliams@gmail.com
# 4                1          3806.10       UK          shawn52@yahoo.com
#
#   Device Type Is Subscribed  Feedback Score
# 0      Mobile           Yes             8.2
# 1      Mobile            No             7.3
# 2      Tablet           Yes             8.5
# 3     Desktop           Yes             9.8
# 4      Tablet            No             7.1

# %%
#Binning Age into categories
bins=[10,30,50,70,90] #Age ranges
labels=["young","Mid","old","Super Old"]
df["age_group"]=pd.cut(df["Age"],bins=bins,labels=labels)

#Displaying the first few rows
df[["Age","age_group"]].head(20)
# Out:
#     Age age_group
# 0    58       old
# 1    65       old
# 2    20     young
# 3    53       old
# 4    46       Mid
# 5    39       Mid
# 6    42       Mid
# 7    64       old
# 8    58       old
# 9    67       old
# 10   47       Mid
# 11   62       old
# 12   28     young
# 13   67       old
# 14   22     young
# 15   43       Mid
# 16   65       old
# 17   23     young
# 18   56       old
# 19   53       old

# %%
#converting date columns to datetime
df['Signup Date']=pd.to_datetime(df['Signup Date'])
df['Last Purchase']=pd.to_datetime(df['Last Purchase'])

# %%
df.dtypes
# Out:
# Customer ID                 int64
# Name                       object
# Age                         int64
# Gender                     object
# Signup Date        datetime64[ns]
# Last Purchase      datetime64[ns]
# Total Purchases             int64
# Total Spent ($)           float64
# Country                    object
# Email                      object
# Device Type                object
# Is Subscribed              object
# Feedback Score            float64
# age_group                category
# dtype: object

# %%
#Time Based features
df['signup_year']=df['Signup Date'].dt.year
df['signup_month']=df['Signup Date'].dt.month

df['days_since_signup']=(pd.Timestamp.today()-df['Signup Date']).dt.days
df['days_since_last_purchase']=(pd.Timestamp.today()-df['Last Purchase']).dt.days

# %%
df.head(20)
# Out:
#     Customer ID                 Name  Age  Gender Signup Date Last Purchase  \
# 0             1         Allison Hill   58    Male  2021-07-12    2022-02-13
# 1             2      Cristian Santos   65    Male  2022-11-24    2024-09-05
# 2             3  Christopher Bernard   20    Male  2022-01-04    2022-06-11
# 3             4         Jamie Arnold   53    Male  2024-02-09    2025-06-11
# 4             5       Victoria Wyatt   46  Female  2024-04-07    2024-06-24
# 5             6        Michael Miles   39  Female  2023-06-27    2024-11-11
# 6             7       Frederick Tate   42    Male  2020-10-25    2022-10-06
# 7             8         Maria Thomas   64  Female  2021-03-04    2023-04-09
# 8             9        Zachary Hicks   58  Female  2020-12-19    2021-05-14
# 9            10    Kendra Maddox DVM   67  Female  2020-08-17    2021-08-07
# 10           11        Nathan Cortez   47  Female  2022-09-16    2023-06-20
# 11           12        Tammy Sellers   62    Male  2023-02-16    2024-07-03
# 12           13        David Bradley   28  Female  2020-11-30    2021-08-23
# 13           14          John Pierce   67    Male  2021-09-15    2023-12-13
# 14           15          Eric Carney   22    Male  2023-05-06    2024-12-06
# 15           16           Kevin Hall   43  Female  2021-07-08    2021-07-19
# 16           17         Carlos Walls   65  Female  2023-01-04    2025-06-17
# 17           18        Matthew Gomez   23    Male  2022-04-30    2024-04-24
# 18           19       Javier Ramirez   56    Male  2021-08-23    2025-05-12
# 19           20        Tammy Allison   53    Male  2021-04-15    2024-09-28
#
#     Total Purchases  Total Spent ($)    Country  \
# 0                 2          3720.67    Germany
# 1                44          3716.31      China
# 2                 6          1132.26      China
# 3                46          3266.93      China
# 4                 1          3806.10         UK
# 5                10          1115.80        UAE
# 6                23          4245.10     Brazil
# 7                35           667.89  Australia
# 8                37          1001.83      India
# 9                 6          4283.82      India
# 10               11          1882.40    Germany
# 11               39          3193.14      China
# 12               25          1386.24      China
# 13               15          4117.92        UAE
# 14               37          4388.02        UAE
# 15               10          1361.16    Germany
# 16               38          2027.03    Germany
# 17                8           806.56         UK
# 18               25          1939.02  Singapore
# 19               44          3617.57      China
#
#                               Email Device Type Is Subscribed  Feedback Score  \
# 0         garzaanthony@robinson.org      Mobile           Yes             8.2
# 1               zlawrence@blake.biz      Mobile            No             7.3
# 2                  wdavis@baker.com      Tablet           Yes             8.5
# 3           janetwilliams@gmail.com     Desktop           Yes             9.8
# 4                 shawn52@yahoo.com      Tablet            No             7.1
# 5       amandasanchez@gray-mayo.net      Mobile           Yes             7.1
# 6              richard13@walter.biz     Desktop           Yes             9.9
# 7                  zhurst@yahoo.com      Mobile            No             8.7
# 8   courtneyconner@carlson-cruz.org      Mobile           Yes             6.8
# 9                daniel62@yahoo.com     Desktop            No             8.3
# 10           meagan89@hernandez.net      Tablet            No             6.8
# 11       rodriguezmichael@yahoo.com      Tablet           Yes             6.8
# 12           spenceamanda@gmail.com      Mobile            No             7.9
# 13          sarahcampos@hotmail.com     Desktop            No             4.6
# 14              omartinez@gmail.com      Mobile            No             4.9
# 15    perezrebecca@jones-young.info      Tablet            No             6.7
# 16         kristenaguirre@gmail.com      Mobile            No             6.0
# 17          brownjessica@wright.net      Tablet            No             8.0
# 18             jmorton@williams.com      Tablet            No             6.1
# 19                 zlewis@gmail.com     Desktop            No             5.4
#
#    age_group  signup_year  signup_month  days_since_signup  \
# 0        old         2021             7               1481
# 1        old         2022            11                981
# 2      young         2022             1               1305
# 3        old         2024             2                539
# 4        Mid         2024             4                481
# 5        Mid         2023             6                766
# 6        Mid         2020            10               1741
# 7        old         2021             3               1611
# 8        old         2020            12               1686
# 9        old         2020             8               1810
# 10       Mid         2022             9               1050
# 11       old         2023             2                897
# 12     young         2020            11               1705
# 13       old         2021             9               1416
# 14     young         2023             5                818
# 15       Mid         2021             7               1485
# 16       old         2023             1                940
# 17     young         2022             4               1189
# 18       old         2021             8               1439
# 19       old         2021             4               1569
#
#     days_since_last_purchase
# 0                       1265
# 1                        330
# 2                       1147
# 3                         51
# 4                        403
# 5                        263
# 6                       1030
# 7                        845
# 8                       1540
# 9                       1455
# 10                       773
# 11                       394
# 12                      1439
# 13                       597
# 14                       238
# 15                      1474
# 16                        45
# 17                       464
# 18                        81
# 19                       307

# %%
#Name features
df['first_name']=df['Name'].apply(lambda x:x.split()[0])
df['last_name']=df['Name'].apply(lambda x:x.split()[-1])
df['name_length']=df['Name'].apply(lambda x:len(x))

# %%
df['is_high_spender']=(df['Total Spent ($)']>5000).astype(int)

# %%
df
# Out:
#       Customer ID                 Name  Age  Gender Signup Date Last Purchase  \
# 0               1         Allison Hill   58    Male  2021-07-12    2022-02-13
# 1               2      Cristian Santos   65    Male  2022-11-24    2024-09-05
# 2               3  Christopher Bernard   20    Male  2022-01-04    2022-06-11
# 3               4         Jamie Arnold   53    Male  2024-02-09    2025-06-11
# 4               5       Victoria Wyatt   46  Female  2024-04-07    2024-06-24
# ...           ...                  ...  ...     ...         ...           ...
# 9995         9996          Beth Brooks   21  Female  2024-01-01    2024-06-18
# 9996         9997        Brittany King   42  Female  2020-11-19    2021-04-16
# 9997         9998          Craig Grant   55  Female  2022-11-18    2024-11-15
# 9998         9999     Christine Wilson   23  Female  2024-03-19    2025-05-26
# 9999        10000      Melissa Jenkins   54  Female  2022-11-22    2024-11-09
#
#       Total Purchases  Total Spent ($)  Country  \
# 0                   2          3720.67  Germany
# 1                  44          3716.31    China
# 2                   6          1132.26    China
# 3                  46          3266.93    China
# 4                   1          3806.10       UK
# ...               ...              ...      ...
# 9995               20          1036.24   Brazil
# 9996               31          3299.25    China
# 9997               14          4293.94       UK
# 9998               50          1199.26      UAE
# 9999               10          4333.38      USA
#
#                                Email  ... age_group signup_year  signup_month  \
# 0          garzaanthony@robinson.org  ...       old        2021             7
# 1                zlawrence@blake.biz  ...       old        2022            11
# 2                   wdavis@baker.com  ...     young        2022             1
# 3            janetwilliams@gmail.com  ...       old        2024             2
# 4                  shawn52@yahoo.com  ...       Mid        2024             4
# ...                              ...  ...       ...         ...           ...
# 9995             vthompson@gmail.com  ...     young        2024             1
# 9996    nbarber@thompson-johnson.biz  ...       Mid        2020            11
# 9997  colonbobby@summers-mullins.com  ...       old        2022            11
# 9998         ramirezdonald@gmail.com  ...     young        2024             3
# 9999         stephenskim@hotmail.com  ...       old        2022            11
#
#      days_since_signup  days_since_last_purchase   first_name  last_name  \
# 0                 1481                      1265      Allison       Hill
# 1                  981                       330     Cristian     Santos
# 2                 1305                      1147  Christopher    Bernard
# 3                  539                        51        Jamie     Arnold
# 4                  481                       403     Victoria      Wyatt
# ...                ...                       ...          ...        ...
# 9995               578                       409         Beth     Brooks
# 9996              1716                      1568     Brittany       King
# 9997               987                       259        Craig      Grant
# 9998               500                        67    Christine     Wilson
# 9999               983                       265      Melissa    Jenkins
#
#       name_length is_high_splender is_high_spender
# 0              12                0               0
# 1              15                0               0
# 2              19                0               0
# 3              12                0               0
# 4              14                0               0
# ...           ...              ...             ...
# 9995           11                0               0
# 9996           13                0               0
# 9997           11                0               0
# 9998           16                0               0
# 9999           15                0               0
#
# [10000 rows x 23 columns]
